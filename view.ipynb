# %%
import matplotlib.pyplot as plt 
import json 
import numpy as np

# %%
with open('matrix012.json', 'r') as f:
    data0 = json.load(f)
data0 = np.array(data0)
with open('astar.json', 'r') as f:
    data = json.load(f)
data = np.array(data)
plt.figure(figsize=[20,20])
plt.subplot(1,2,1)
plt.imshow(data0)
plt.subplot(1,2,2)
plt.imshow(data)
plt.show()
