# %%
import matplotlib.pyplot as plt 
import json 
import numpy as np

# %%
# for i in range(1, 10):
#     with open('input_vec_{}.json'.format(i*20), 'r') as f:
#         data0 = json.load(f)
#     data = np.array(data0).reshape(7,256,256)
#     print(data.shape)
#     curr_map = data[4]
#     path = data[5]
#     plt.figure(figsize=[3,3])
#     plt.imshow(curr_map + path*2)
#     plt.show()

# %%
for i in range(1,50,2):
    with open('astar{}.json'.format(i), 'r') as f:
        data = json.load(f)
    data = np.array(data)
    plt.figure(figsize=[10,10])
    plt.imshow(data)
    plt.show()
